# %% [markdown]
# # Using a sequential Monte Carlo model to localize sensors based on radio pings: process ping data

# %% [markdown]
# ## Load the libraries we need

# %% [markdown]
# Load the third-party libraries.

# %%
import numpy as np
import pandas as pd
import os
import dateutil.parser

# %% [markdown]
# Load our `smclocalize` module.

# %%
from smclocalize import *

# %% [markdown]
# Load our `sensei_client` module.

# %%
import sensei

# %% [markdown]
# ## Set the base data paths

# %%
data_path = './data/'
data_run_directory = 'aster_180313/'

# %% [markdown]
# ## Load the ping data

# %%
api = sensei.Api(
    username="ted.quinn@wildflowerschools.org",
    password="YE9j9FuFRa")

# %%
obs = api.get_radio_observations(
    1289,
    start_time=dateutil.parser.parse('2018-03-13T23:35:00Z'),
    end_time=dateutil.parser.parse('2018-03-14T01:25:00Z'),
    json_rep=True)

# %%
all_data = pd.DataFrame(obs)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33378 entries, 0 to 33377
# Data columns (total 7 columns):
# classroom_id    33378 non-null int64
# local_id        33378 non-null int64
# local_type      33378 non-null object
# observed_at     33378 non-null object
# remote_id       33378 non-null int64
# remote_type     33378 non-null object
# rssi            33378 non-null float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.8+ MB

# %%
all_data['observed_at'] = pd.to_datetime(
            all_data['observed_at'])
# all_data['observed_at'] = pd.Series(
#     pd.Index(
#         pd.to_datetime(
#             all_data['observed_at'])).tz_localize('UTC'))

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33378 entries, 0 to 33377
# Data columns (total 7 columns):
# classroom_id    33378 non-null int64
# local_id        33378 non-null int64
# local_type      33378 non-null object
# observed_at     33378 non-null datetime64[ns]
# remote_id       33378 non-null int64
# remote_type     33378 non-null object
# rssi            33378 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 1.8+ MB

# %%
all_data
# Out:
#        classroom_id  local_id local_type         observed_at  remote_id  \
# 0              1289        29       area 2018-03-13 23:35:00      28352
# 1              1289        29       area 2018-03-13 23:35:00      28348
# 2              1289        31       area 2018-03-13 23:35:00      28348
# 3              1289        36       area 2018-03-13 23:35:00      28348
# 4              1289     28352      child 2018-03-13 23:35:00      28348
# 5              1289     28352      child 2018-03-13 23:35:00         29
# 6              1289     28354      child 2018-03-13 23:35:00      28348
# 7              1289     28354      child 2018-03-13 23:35:00         31
# 8              1289     28348      child 2018-03-13 23:35:00      28352
# 9              1289     28352      child 2018-03-13 23:35:00      36212
# 10             1289     37760      child 2018-03-13 23:35:00      30007
# 11             1289     37760      child 2018-03-13 23:35:00      36212
# 12             1289     57651      child 2018-03-13 23:35:00      37757
# 13             1289     57651      child 2018-03-13 23:35:00      38394
# 14             1289     37757      child 2018-03-13 23:35:00      30007
# 15             1289     37757      child 2018-03-13 23:35:00      28354
# 16             1289     55514      child 2018-03-13 23:35:00      36212
# 17             1289     30007      child 2018-03-13 23:35:00      37757
# 18             1289     28354      child 2018-03-13 23:35:00      37757
# 19             1289     28354      child 2018-03-13 23:35:00      38394
# 20             1289     38394      child 2018-03-13 23:35:00      37757
# 21             1289     38394      child 2018-03-13 23:35:00      28354
# 22             1289     37758      child 2018-03-13 23:35:00      30007
# 23             1289     36212      child 2018-03-13 23:35:00      28352
# 24             1289     38394      child 2018-03-13 23:35:00      57651
# 25             1289     57651      child 2018-03-13 23:35:00      28354
# 26             1289     37757      child 2018-03-13 23:35:00      38394
# 27             1289     37758      child 2018-03-13 23:35:00      36212
# 28             1289     28348      child 2018-03-13 23:35:00     688561
# 29             1289    688561   material 2018-03-13 23:35:00      28348
# ...             ...       ...        ...                 ...        ...
# 33348          1289     37757      child 2018-03-14 01:00:00      38394
# 33349          1289     28348      child 2018-03-14 01:00:00     688570
# 33350          1289        54       area 2018-03-14 01:00:00      28348
# 33351          1289     28348      child 2018-03-14 01:00:00      55514
# 33352          1289     55514      child 2018-03-14 01:00:00      28348
# 33353          1289     38394      child 2018-03-14 01:00:00         31
# 33354          1289        50       area 2018-03-14 01:00:00      28354
# 33355          1289        29       area 2018-03-14 01:00:00      55514
# 33356          1289        53       area 2018-03-14 01:00:00      55514
# 33357          1289     36212      child 2018-03-14 01:00:00     688570
# 33358          1289     37760      child 2018-03-14 01:00:00         54
# 33359          1289        36       area 2018-03-14 01:00:00      37757
# 33360          1289     55514      child 2018-03-14 01:00:00         29
# 33361          1289     37760      child 2018-03-14 01:00:00     688561
# 33362          1289        31       area 2018-03-14 01:00:00      38394
# 33363          1289     37757      child 2018-03-14 01:00:00      11028
# 33364          1289     11029    teacher 2018-03-14 01:00:00     688570
# 33365          1289     36212      child 2018-03-14 01:00:00      11029
# 33366          1289     11028    teacher 2018-03-14 01:00:00         52
# 33367          1289     11029    teacher 2018-03-14 01:00:00      55514
# 33368          1289        52       area 2018-03-14 01:00:00      11029
# 33369          1289     11028    teacher 2018-03-14 01:00:00      38394
# 33370          1289     11028    teacher 2018-03-14 01:00:00      37758
# 33371          1289     57651      child 2018-03-14 01:00:00      11028
# 33372          1289        54       area 2018-03-14 01:00:00      11029
# 33373          1289     11028    teacher 2018-03-14 01:00:00      57651
# 33374          1289     28352      child 2018-03-14 01:00:00     688570
# 33375          1289     55514      child 2018-03-14 01:00:00      11029
# 33376          1289        52       area 2018-03-14 01:00:00      38394
# 33377          1289     28352      child 2018-03-14 01:00:00         50
#
#       remote_type  rssi
# 0           child -70.0
# 1           child -77.0
# 2           child -90.0
# 3           child -90.0
# 4           child -60.0
# 5            area -70.0
# 6           child -86.0
# 7            area -85.0
# 8           child -61.0
# 9           child -71.0
# 10          child -66.0
# 11          child -73.0
# 12          child -63.0
# 13          child -63.0
# 14          child -80.0
# 15          child -62.0
# 16          child -76.0
# 17          child -80.0
# 18          child -63.0
# 19          child -70.0
# 20          child -65.0
# 21          child -69.0
# 22          child -58.0
# 23          child -71.0
# 24          child -62.0
# 25          child -67.0
# 26          child -65.0
# 27          child -73.0
# 28       material -74.0
# 29          child -73.0
# ...           ...   ...
# 33348       child -65.0
# 33349    material -82.0
# 33350       child -72.0
# 33351       child -77.0
# 33352       child -77.0
# 33353        area -81.0
# 33354       child -83.0
# 33355       child -71.0
# 33356       child -80.0
# 33357    material -75.0
# 33358        area -58.0
# 33359       child -88.0
# 33360        area -71.0
# 33361    material -73.0
# 33362       child -81.0
# 33363     teacher -84.0
# 33364    material -86.0
# 33365     teacher -62.0
# 33366        area -71.0
# 33367       child -62.0
# 33368     teacher -83.0
# 33369       child -81.0
# 33370       child -59.0
# 33371     teacher -80.0
# 33372     teacher -76.0
# 33373       child -82.0
# 33374    material -79.0
# 33375     teacher -62.0
# 33376       child -84.0
# 33377        area -76.0
#
# [33378 rows x 7 columns]

# %% [markdown]
# ## Filter the ping data

# %% [markdown]
# Here is where we do any manual cleaning and filtering of the data.

# %%
usable_data = all_data
# usable_data = all_data[(all_data['remote_id'] != 8) &
#                        (all_data['local_id'] != 8)].reset_index(drop=True)

# %% [markdown]
# ## Save the ping data in dataframe format

# %%
usable_data.to_pickle(os.path.join(
    data_path,
    data_run_directory,
    'pickle/usable_data.pkl'))

# %% [markdown]
# ## (Re)load the ping data in dataframe format

# %%
usable_data = pd.read_pickle(os.path.join(
    data_path,
    data_run_directory,
    'pickle/usable_data.pkl'))

# %% [markdown]
# ## Extract entity IDs

# %% [markdown]
# Extract the list of entity IDs in our data set corresponding to each type of sensors. These lists are the basis for our variable structure.

# %%
child_entity_ids = np.union1d(pd.unique(usable_data[usable_data.local_type == 'child'].local_id),
                              pd.unique(usable_data[usable_data.remote_type == 'child'].remote_id)).tolist()
material_entity_ids = np.union1d(pd.unique(usable_data[usable_data.local_type == 'material'].local_id),
                                 pd.unique(usable_data[usable_data.remote_type == 'material'].remote_id)).tolist()
teacher_entity_ids = np.union1d(pd.unique(usable_data[usable_data.local_type == 'teacher'].local_id),
                                pd.unique(usable_data[usable_data.remote_type == 'teacher'].remote_id)).tolist()
area_entity_ids = np.union1d(pd.unique(usable_data[usable_data.local_type == 'area'].local_id),
                             pd.unique(usable_data[usable_data.remote_type == 'area'].remote_id)).tolist()

# %%
len(child_entity_ids) + len(material_entity_ids) + len(teacher_entity_ids) + len(area_entity_ids)
# Out:
# 26

# %% [markdown]
# ## Define the variable structure for the model

# %% [markdown]
# Using the lists of entity IDs, define an instance of the `SensorVariableStructure` class. This class provides a whole bunch of variables and helper functions for working with the data.

# %%
variable_structure = SensorVariableStructure(child_entity_ids,
                                             material_entity_ids,
                                             teacher_entity_ids,
                                             area_entity_ids)

# %% [markdown]
# ## Restructure the ping data for use in the model

# %% [markdown]
# Using the helper functions from the `SensorVariableStructure` class, parse the data into arrays which represent the discrete and continuous components of the $\mathbf{Y}$ variables which we will use in the model.

# %% [markdown]
# In the below, we parse the data separately for each time step in order to mimic the real-time use case. There is also a helper function called `sensor_data_parse_multiple_timesteps()` for parsing an entire data set containing many timesteps (not shown here).

# %% [markdown]
# For `y_discrete_t`, use 0 to indicate that a ping was received and 1 to indicate that a ping was not received (don't ask). For `y_continuous_t`, we convert the integer RSSI values to floats (since we're treating RSSI as a continuous variable) and we just enter a 0.0 value for RSSI if no ping was received.

# %%
timestamps = np.sort(usable_data['observed_at'].unique())
num_timesteps = len(timestamps)
y_discrete_t = np.ones(
    (num_timesteps, variable_structure.num_y_discrete_vars),
    dtype='int')
y_continuous_t = np.zeros(
    (num_timesteps, variable_structure.num_y_continuous_vars),
    dtype='float')
for t_index in range(num_timesteps):
    (y_discrete_t[t_index], y_continuous_t[t_index]) = variable_structure.sensor_data_parse_one_timestep(
        usable_data[usable_data['observed_at'] == timestamps[t_index]])

# %% [markdown]
# Apply some basic sanity checks.

# %%
timestamp_range = pd.date_range(usable_data['observed_at'].min(), usable_data['observed_at'].max(), freq='10S')

# %%
np.setdiff1d(timestamp_range, timestamps)
# Out:
# array([], dtype='datetime64[ns]')

# %% [markdown]
# Check to make sure that the post-processed data and the pre-processed data agree on the total number of pings received.

# %%
np.sum(y_discrete_t == 0)
# Out:
# 33378

# %%
np.sum(y_continuous_t != 0.0)
# Out:
# 33378

# %%
len(usable_data)
# Out:
# 33378

# %% [markdown]
# ## Save the ping data in the format required by the model

# %%
np.savez(
    os.path.join(
        data_path,
        data_run_directory,
        'numpy/ping_data.npz'),
    child_entity_ids = child_entity_ids,
    material_entity_ids = material_entity_ids,
    teacher_entity_ids = teacher_entity_ids,
    area_entity_ids = area_entity_ids,
    timestamps = timestamps,
    num_timesteps = num_timesteps,
    y_discrete_t = y_discrete_t,
    y_continuous_t = y_continuous_t)

# %% [markdown]
# ## Calculate and save the same data in matrix format

# %%
y_discrete_all_sensors_t = np.ones(
    (num_timesteps, variable_structure.num_sensors, variable_structure.num_sensors),
    dtype='int')
y_continuous_all_sensors_t = np.zeros(
    (num_timesteps, variable_structure.num_sensors, variable_structure.num_sensors),
    dtype='float')
for t_index in range(num_timesteps):
    (y_discrete_all_sensors_t[t_index], y_continuous_all_sensors_t[t_index]) = variable_structure.sensor_data_all_sensors_one_timestep(
        usable_data[usable_data['observed_at'] == timestamps[t_index]])

# %%
np.savez(
    os.path.join(
        data_path,
        data_run_directory,
        'numpy/ping_data_all_sensors.npz'),
    y_discrete_all_sensors_t = y_discrete_all_sensors_t,
    y_continuous_all_sensors_t = y_continuous_all_sensors_t)

# %% [markdown]
# ## Load the moving sensor ground truth data

# %%
period_timing_data = pd.read_csv(
    os.path.join(
        data_path,
        data_run_directory,
        'csv/aster_180313_period_timing.csv'))

# %%
sensor_clusters_data = pd.read_csv(
    os.path.join(
        data_path,
        data_run_directory,
        'csv/aster_180313_sensor_clusters.csv'))

# %%
cluster_positions_data = pd.read_csv(
    os.path.join(
        data_path,
        data_run_directory,
        'csv/aster_180313_cluster_positions.csv'))

# %%
period_timing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
# period        2 non-null int64
# start_time    2 non-null object
# end_time      2 non-null object
# dtypes: int64(1), object(2)
# memory usage: 128.0+ bytes

# %%
period_timing_data
# Out:
#    period            start_time              end_time
# 0       1  2018-03-13 23:36:00Z  2018-03-13 23:52:00Z
# 1       2  2018-03-13 23:54:00Z  2018-03-14 01:24:00Z

# %%
period_timing_data['start_time'] = pd.to_datetime(
    period_timing_data['start_time'])

# %%
period_timing_data['end_time'] = pd.to_datetime(
    period_timing_data['end_time'])

# %%
period_timing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
# period        2 non-null int64
# start_time    2 non-null datetime64[ns]
# end_time      2 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1)
# memory usage: 128.0 bytes

# %%
period_timing_data
# Out:
#    period          start_time            end_time
# 0       1 2018-03-13 23:36:00 2018-03-13 23:52:00
# 1       2 2018-03-13 23:54:00 2018-03-14 01:24:00

# %%
sensor_clusters_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
# period       26 non-null int64
# cluster      26 non-null object
# sensor_id    26 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 704.0+ bytes

# %%
sensor_clusters_data
# Out:
#     period          cluster  sensor_id
# 0        1       Post table         11
# 1        1       Post table         12
# 2        1       Post table         14
# 3        1       Bead table         17
# 4        1       Bead table         18
# 5        1       Bead table         19
# 6        1       Bead table         21
# 7        1  Geography floor         13
# 8        1  Geography floor         15
# 9        1  Geography floor         16
# 10       1  Geography floor         20
# 11       1     Drying table         30
# 12       1     Drying table         31
# 13       2       Post table         18
# 14       2       Post table         17
# 15       2       Post table         12
# 16       2       Bead table         19
# 17       2       Bead table         21
# 18       2       Bead table         16
# 19       2       Bead table         31
# 20       2  Geography floor         15
# 21       2  Geography floor         13
# 22       2  Geography floor         14
# 23       2  Geography floor         20
# 24       2     Drying table         11
# 25       2     Drying table         30

# %%
cluster_positions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# cluster     4 non-null object
# l_center    4 non-null float64
# w_center    4 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 176.0+ bytes

# %%
cluster_positions_data
# Out:
#            cluster  l_center  w_center
# 0       Post table    3.7592    3.4798
# 1       Bead table    5.1308    1.4732
# 2  Geography floor    8.4582    4.4958
# 3     Drying table    9.6774    2.1590

# %% [markdown]
# ## Expand into a table of observations

# %%
dataframes = []
for i in range(len(period_timing_data)):
    timestamps_df = pd.DataFrame({
        'observed_at': pd.date_range(
                period_timing_data.iloc[i, 1],
                period_timing_data.iloc[i, 2],
                freq='10S'),
        'period': period_timing_data.iloc[i, 0]})
    dataframes.append(timestamps_df)
period_timing_data_expanded = pd.concat(
    dataframes,
    ignore_index=True)

# %%
period_timing_data_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 2 columns):
# observed_at    638 non-null datetime64[ns]
# period         638 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 10.0 KB

# %%
period_timing_data_expanded
# Out:
#             observed_at  period
# 0   2018-03-13 23:36:00       1
# 1   2018-03-13 23:36:10       1
# 2   2018-03-13 23:36:20       1
# 3   2018-03-13 23:36:30       1
# 4   2018-03-13 23:36:40       1
# 5   2018-03-13 23:36:50       1
# 6   2018-03-13 23:37:00       1
# 7   2018-03-13 23:37:10       1
# 8   2018-03-13 23:37:20       1
# 9   2018-03-13 23:37:30       1
# 10  2018-03-13 23:37:40       1
# 11  2018-03-13 23:37:50       1
# 12  2018-03-13 23:38:00       1
# 13  2018-03-13 23:38:10       1
# 14  2018-03-13 23:38:20       1
# 15  2018-03-13 23:38:30       1
# 16  2018-03-13 23:38:40       1
# 17  2018-03-13 23:38:50       1
# 18  2018-03-13 23:39:00       1
# 19  2018-03-13 23:39:10       1
# 20  2018-03-13 23:39:20       1
# 21  2018-03-13 23:39:30       1
# 22  2018-03-13 23:39:40       1
# 23  2018-03-13 23:39:50       1
# 24  2018-03-13 23:40:00       1
# 25  2018-03-13 23:40:10       1
# 26  2018-03-13 23:40:20       1
# 27  2018-03-13 23:40:30       1
# 28  2018-03-13 23:40:40       1
# 29  2018-03-13 23:40:50       1
# ..                  ...     ...
# 608 2018-03-14 01:19:10       2
# 609 2018-03-14 01:19:20       2
# 610 2018-03-14 01:19:30       2
# 611 2018-03-14 01:19:40       2
# 612 2018-03-14 01:19:50       2
# 613 2018-03-14 01:20:00       2
# 614 2018-03-14 01:20:10       2
# 615 2018-03-14 01:20:20       2
# 616 2018-03-14 01:20:30       2
# 617 2018-03-14 01:20:40       2
# 618 2018-03-14 01:20:50       2
# 619 2018-03-14 01:21:00       2
# 620 2018-03-14 01:21:10       2
# 621 2018-03-14 01:21:20       2
# 622 2018-03-14 01:21:30       2
# 623 2018-03-14 01:21:40       2
# 624 2018-03-14 01:21:50       2
# 625 2018-03-14 01:22:00       2
# 626 2018-03-14 01:22:10       2
# 627 2018-03-14 01:22:20       2
# 628 2018-03-14 01:22:30       2
# 629 2018-03-14 01:22:40       2
# 630 2018-03-14 01:22:50       2
# 631 2018-03-14 01:23:00       2
# 632 2018-03-14 01:23:10       2
# 633 2018-03-14 01:23:20       2
# 634 2018-03-14 01:23:30       2
# 635 2018-03-14 01:23:40       2
# 636 2018-03-14 01:23:50       2
# 637 2018-03-14 01:24:00       2
#
# [638 rows x 2 columns]

# %%
sensor_cluster_positions_data = pd.merge(
    sensor_clusters_data,
    cluster_positions_data)

# %%
sensor_cluster_positions_data
# Out:
#     period          cluster  sensor_id  l_center  w_center
# 0        1       Post table         11    3.7592    3.4798
# 1        1       Post table         12    3.7592    3.4798
# 2        1       Post table         14    3.7592    3.4798
# 3        2       Post table         18    3.7592    3.4798
# 4        2       Post table         17    3.7592    3.4798
# 5        2       Post table         12    3.7592    3.4798
# 6        1       Bead table         17    5.1308    1.4732
# 7        1       Bead table         18    5.1308    1.4732
# 8        1       Bead table         19    5.1308    1.4732
# 9        1       Bead table         21    5.1308    1.4732
# 10       2       Bead table         19    5.1308    1.4732
# 11       2       Bead table         21    5.1308    1.4732
# 12       2       Bead table         16    5.1308    1.4732
# 13       2       Bead table         31    5.1308    1.4732
# 14       1  Geography floor         13    8.4582    4.4958
# 15       1  Geography floor         15    8.4582    4.4958
# 16       1  Geography floor         16    8.4582    4.4958
# 17       1  Geography floor         20    8.4582    4.4958
# 18       2  Geography floor         15    8.4582    4.4958
# 19       2  Geography floor         13    8.4582    4.4958
# 20       2  Geography floor         14    8.4582    4.4958
# 21       2  Geography floor         20    8.4582    4.4958
# 22       1     Drying table         30    9.6774    2.1590
# 23       1     Drying table         31    9.6774    2.1590
# 24       2     Drying table         11    9.6774    2.1590
# 25       2     Drying table         30    9.6774    2.1590

# %%
sensor_positions_data = sensor_cluster_positions_data[['period', 'sensor_id', 'l_center', 'w_center']]

# %%
sensor_positions_data
# Out:
#     period  sensor_id  l_center  w_center
# 0        1         11    3.7592    3.4798
# 1        1         12    3.7592    3.4798
# 2        1         14    3.7592    3.4798
# 3        2         18    3.7592    3.4798
# 4        2         17    3.7592    3.4798
# 5        2         12    3.7592    3.4798
# 6        1         17    5.1308    1.4732
# 7        1         18    5.1308    1.4732
# 8        1         19    5.1308    1.4732
# 9        1         21    5.1308    1.4732
# 10       2         19    5.1308    1.4732
# 11       2         21    5.1308    1.4732
# 12       2         16    5.1308    1.4732
# 13       2         31    5.1308    1.4732
# 14       1         13    8.4582    4.4958
# 15       1         15    8.4582    4.4958
# 16       1         16    8.4582    4.4958
# 17       1         20    8.4582    4.4958
# 18       2         15    8.4582    4.4958
# 19       2         13    8.4582    4.4958
# 20       2         14    8.4582    4.4958
# 21       2         20    8.4582    4.4958
# 22       1         30    9.6774    2.1590
# 23       1         31    9.6774    2.1590
# 24       2         11    9.6774    2.1590
# 25       2         30    9.6774    2.1590

# %%
sensor_positions_data['l'] = sensor_positions_data['l_center'] + np.random.normal(
    0,
    0.1,
    len(sensor_positions_data))

# %%
sensor_positions_data['w'] = sensor_positions_data['w_center'] + np.random.normal(
    0,
    0.1,
    len(sensor_positions_data))

# %%
sensor_positions_data
# Out:
#     period  sensor_id  l_center  w_center         l         w
# 0        1         11    3.7592    3.4798  3.629785  3.549055
# 1        1         12    3.7592    3.4798  3.832900  3.510205
# 2        1         14    3.7592    3.4798  3.854473  3.567772
# 3        2         18    3.7592    3.4798  3.724507  3.533056
# 4        2         17    3.7592    3.4798  3.717349  3.502710
# 5        2         12    3.7592    3.4798  3.756844  3.528686
# 6        1         17    5.1308    1.4732  5.153526  1.362054
# 7        1         18    5.1308    1.4732  5.124096  1.287351
# 8        1         19    5.1308    1.4732  5.148084  1.549869
# 9        1         21    5.1308    1.4732  5.168075  1.533441
# 10       2         19    5.1308    1.4732  5.106164  1.518721
# 11       2         21    5.1308    1.4732  5.265208  1.439371
# 12       2         16    5.1308    1.4732  5.086548  1.422751
# 13       2         31    5.1308    1.4732  5.059857  1.447721
# 14       1         13    8.4582    4.4958  8.425577  4.324590
# 15       1         15    8.4582    4.4958  8.414899  4.506245
# 16       1         16    8.4582    4.4958  8.446923  4.507708
# 17       1         20    8.4582    4.4958  8.437763  4.551312
# 18       2         15    8.4582    4.4958  8.465999  4.580597
# 19       2         13    8.4582    4.4958  8.513320  4.340901
# 20       2         14    8.4582    4.4958  8.397499  4.318761
# 21       2         20    8.4582    4.4958  8.566187  4.473784
# 22       1         30    9.6774    2.1590  9.655660  2.234919
# 23       1         31    9.6774    2.1590  9.635034  2.289426
# 24       2         11    9.6774    2.1590  9.640769  2.318698
# 25       2         30    9.6774    2.1590  9.776886  2.110122

# %%
observations_data = pd.merge(
    period_timing_data_expanded,
    sensor_positions_data)

# %%
observations_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8294 entries, 0 to 8293
# Data columns (total 7 columns):
# observed_at    8294 non-null datetime64[ns]
# period         8294 non-null int64
# sensor_id      8294 non-null int64
# l_center       8294 non-null float64
# w_center       8294 non-null float64
# l              8294 non-null float64
# w              8294 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(2)
# memory usage: 518.4 KB

# %%
observations_data
# Out:
#              observed_at  period  sensor_id  l_center  w_center         l  \
# 0    2018-03-13 23:36:00       1         11    3.7592    3.4798  3.629785
# 1    2018-03-13 23:36:00       1         12    3.7592    3.4798  3.832900
# 2    2018-03-13 23:36:00       1         14    3.7592    3.4798  3.854473
# 3    2018-03-13 23:36:00       1         17    5.1308    1.4732  5.153526
# 4    2018-03-13 23:36:00       1         18    5.1308    1.4732  5.124096
# 5    2018-03-13 23:36:00       1         19    5.1308    1.4732  5.148084
# 6    2018-03-13 23:36:00       1         21    5.1308    1.4732  5.168075
# 7    2018-03-13 23:36:00       1         13    8.4582    4.4958  8.425577
# 8    2018-03-13 23:36:00       1         15    8.4582    4.4958  8.414899
# 9    2018-03-13 23:36:00       1         16    8.4582    4.4958  8.446923
# 10   2018-03-13 23:36:00       1         20    8.4582    4.4958  8.437763
# 11   2018-03-13 23:36:00       1         30    9.6774    2.1590  9.655660
# 12   2018-03-13 23:36:00       1         31    9.6774    2.1590  9.635034
# 13   2018-03-13 23:36:10       1         11    3.7592    3.4798  3.629785
# 14   2018-03-13 23:36:10       1         12    3.7592    3.4798  3.832900
# 15   2018-03-13 23:36:10       1         14    3.7592    3.4798  3.854473
# 16   2018-03-13 23:36:10       1         17    5.1308    1.4732  5.153526
# 17   2018-03-13 23:36:10       1         18    5.1308    1.4732  5.124096
# 18   2018-03-13 23:36:10       1         19    5.1308    1.4732  5.148084
# 19   2018-03-13 23:36:10       1         21    5.1308    1.4732  5.168075
# 20   2018-03-13 23:36:10       1         13    8.4582    4.4958  8.425577
# 21   2018-03-13 23:36:10       1         15    8.4582    4.4958  8.414899
# 22   2018-03-13 23:36:10       1         16    8.4582    4.4958  8.446923
# 23   2018-03-13 23:36:10       1         20    8.4582    4.4958  8.437763
# 24   2018-03-13 23:36:10       1         30    9.6774    2.1590  9.655660
# 25   2018-03-13 23:36:10       1         31    9.6774    2.1590  9.635034
# 26   2018-03-13 23:36:20       1         11    3.7592    3.4798  3.629785
# 27   2018-03-13 23:36:20       1         12    3.7592    3.4798  3.832900
# 28   2018-03-13 23:36:20       1         14    3.7592    3.4798  3.854473
# 29   2018-03-13 23:36:20       1         17    5.1308    1.4732  5.153526
# ...                  ...     ...        ...       ...       ...       ...
# 8264 2018-03-14 01:23:40       2         14    8.4582    4.4958  8.397499
# 8265 2018-03-14 01:23:40       2         20    8.4582    4.4958  8.566187
# 8266 2018-03-14 01:23:40       2         11    9.6774    2.1590  9.640769
# 8267 2018-03-14 01:23:40       2         30    9.6774    2.1590  9.776886
# 8268 2018-03-14 01:23:50       2         18    3.7592    3.4798  3.724507
# 8269 2018-03-14 01:23:50       2         17    3.7592    3.4798  3.717349
# 8270 2018-03-14 01:23:50       2         12    3.7592    3.4798  3.756844
# 8271 2018-03-14 01:23:50       2         19    5.1308    1.4732  5.106164
# 8272 2018-03-14 01:23:50       2         21    5.1308    1.4732  5.265208
# 8273 2018-03-14 01:23:50       2         16    5.1308    1.4732  5.086548
# 8274 2018-03-14 01:23:50       2         31    5.1308    1.4732  5.059857
# 8275 2018-03-14 01:23:50       2         15    8.4582    4.4958  8.465999
# 8276 2018-03-14 01:23:50       2         13    8.4582    4.4958  8.513320
# 8277 2018-03-14 01:23:50       2         14    8.4582    4.4958  8.397499
# 8278 2018-03-14 01:23:50       2         20    8.4582    4.4958  8.566187
# 8279 2018-03-14 01:23:50       2         11    9.6774    2.1590  9.640769
# 8280 2018-03-14 01:23:50       2         30    9.6774    2.1590  9.776886
# 8281 2018-03-14 01:24:00       2         18    3.7592    3.4798  3.724507
# 8282 2018-03-14 01:24:00       2         17    3.7592    3.4798  3.717349
# 8283 2018-03-14 01:24:00       2         12    3.7592    3.4798  3.756844
# 8284 2018-03-14 01:24:00       2         19    5.1308    1.4732  5.106164
# 8285 2018-03-14 01:24:00       2         21    5.1308    1.4732  5.265208
# 8286 2018-03-14 01:24:00       2         16    5.1308    1.4732  5.086548
# 8287 2018-03-14 01:24:00       2         31    5.1308    1.4732  5.059857
# 8288 2018-03-14 01:24:00       2         15    8.4582    4.4958  8.465999
# 8289 2018-03-14 01:24:00       2         13    8.4582    4.4958  8.513320
# 8290 2018-03-14 01:24:00       2         14    8.4582    4.4958  8.397499
# 8291 2018-03-14 01:24:00       2         20    8.4582    4.4958  8.566187
# 8292 2018-03-14 01:24:00       2         11    9.6774    2.1590  9.640769
# 8293 2018-03-14 01:24:00       2         30    9.6774    2.1590  9.776886
#
#              w
# 0     3.549055
# 1     3.510205
# 2     3.567772
# 3     1.362054
# 4     1.287351
# 5     1.549869
# 6     1.533441
# 7     4.324590
# 8     4.506245
# 9     4.507708
# 10    4.551312
# 11    2.234919
# 12    2.289426
# 13    3.549055
# 14    3.510205
# 15    3.567772
# 16    1.362054
# 17    1.287351
# 18    1.549869
# 19    1.533441
# 20    4.324590
# 21    4.506245
# 22    4.507708
# 23    4.551312
# 24    2.234919
# 25    2.289426
# 26    3.549055
# 27    3.510205
# 28    3.567772
# 29    1.362054
# ...        ...
# 8264  4.318761
# 8265  4.473784
# 8266  2.318698
# 8267  2.110122
# 8268  3.533056
# 8269  3.502710
# 8270  3.528686
# 8271  1.518721
# 8272  1.439371
# 8273  1.422751
# 8274  1.447721
# 8275  4.580597
# 8276  4.340901
# 8277  4.318761
# 8278  4.473784
# 8279  2.318698
# 8280  2.110122
# 8281  3.533056
# 8282  3.502710
# 8283  3.528686
# 8284  1.518721
# 8285  1.439371
# 8286  1.422751
# 8287  1.447721
# 8288  4.580597
# 8289  4.340901
# 8290  4.318761
# 8291  4.473784
# 8292  2.318698
# 8293  2.110122
#
# [8294 rows x 7 columns]

# %% [markdown]
# ## Get the mappings between sensor IDs and entity IDs

# %%
sensor_mappings = pd.DataFrame(api.get_sensor_mappings(1289, json_rep=True))

# %%
sensor_mappings
# Out:
#     classroom_id end_time  entity_id entity_type  sensor_id  \
# 0           1289     None      28348       child         18
# 1           1289     None      28349       child         28
# 2           1289     None      28350       child         26
# 3           1289     None      28352       child         17
# 4           1289     None      28354       child         16
# 5           1289     None      30007       child         14
# 6           1289     None      36212       child         19
# 7           1289     None      37757       child         20
# 8           1289     None      37758       child         11
# 9           1289     None      37760       child         12
# 10          1289     None      38394       child         15
# 11          1289     None      55514       child         21
# 12          1289     None      57651       child         13
# 13          1289     None      11028     teacher         30
# 14          1289     None      11029     teacher         31
# 15          1289     None         29    material         35
# 16          1289     None         30    material         42
# 17          1289     None         31    material         36
# 18          1289     None         32    material         37
# 19          1289     None         33    material         38
# 20          1289     None         34    material         39
# 21          1289     None     688554    material         41
# 22          1289     None     688561    material         44
# 23          1289     None     688570    material         40
# 24          1289     None         29        area          3
# 25          1289     None         31        area          1
# 26          1289     None         36        area         48
# 27          1289     None         49        area          2
# 28          1289     None         50        area          4
# 29          1289     None         51        area          5
# 30          1289     None         52        area          6
# 31          1289     None         53        area          7
# 32          1289     None         54        area         49
#
#                      start_time
# 0   2018-03-13T21:07:21.132772Z
# 1   2018-03-13T21:07:21.141314Z
# 2   2018-03-13T21:07:21.152603Z
# 3   2018-03-13T21:07:21.163027Z
# 4   2018-03-13T21:07:21.172362Z
# 5   2018-03-13T21:07:21.183572Z
# 6   2018-03-13T21:07:21.194333Z
# 7   2018-03-13T21:07:21.205041Z
# 8   2018-03-13T21:07:21.215948Z
# 9   2018-03-13T21:07:21.227008Z
# 10  2018-03-13T21:07:21.238144Z
# 11  2018-03-13T21:07:21.249465Z
# 12  2018-03-13T21:07:21.260408Z
# 13  2018-03-13T21:07:21.269928Z
# 14  2018-03-13T21:07:21.279935Z
# 15  2018-03-13T21:07:21.289673Z
# 16  2018-03-13T21:07:21.299011Z
# 17  2018-03-13T21:07:21.308692Z
# 18  2018-03-13T21:07:21.318010Z
# 19  2018-03-13T21:07:21.328427Z
# 20  2018-03-13T21:07:21.337838Z
# 21  2018-03-13T21:07:21.347773Z
# 22  2018-03-13T21:07:21.357913Z
# 23  2018-03-13T21:07:21.367487Z
# 24  2018-03-13T21:07:21.377249Z
# 25  2018-03-13T21:07:21.387412Z
# 26  2018-03-13T21:07:21.421165Z
# 27  2018-03-13T21:07:21.429380Z
# 28  2018-03-13T21:07:21.438772Z
# 29  2018-03-13T21:07:21.448997Z
# 30  2018-03-13T21:07:21.457667Z
# 31  2018-03-13T21:07:21.466854Z
# 32  2018-03-13T21:07:21.476705Z

# %%
entity_id_lookup = sensor_mappings[['sensor_id', 'entity_type', 'entity_id']]

# %%
entity_id_lookup
# Out:
#     sensor_id entity_type  entity_id
# 0          18       child      28348
# 1          28       child      28349
# 2          26       child      28350
# 3          17       child      28352
# 4          16       child      28354
# 5          14       child      30007
# 6          19       child      36212
# 7          20       child      37757
# 8          11       child      37758
# 9          12       child      37760
# 10         15       child      38394
# 11         21       child      55514
# 12         13       child      57651
# 13         30     teacher      11028
# 14         31     teacher      11029
# 15         35    material         29
# 16         42    material         30
# 17         36    material         31
# 18         37    material         32
# 19         38    material         33
# 20         39    material         34
# 21         41    material     688554
# 22         44    material     688561
# 23         40    material     688570
# 24          3        area         29
# 25          1        area         31
# 26         48        area         36
# 27          2        area         49
# 28          4        area         50
# 29          5        area         51
# 30          6        area         52
# 31          7        area         53
# 32         49        area         54

# %% [markdown]
# ## Convert moving sensor ground truth data from sensor IDs to entity IDs

# %%
moving_sensors_data = pd.merge(
    observations_data,
    entity_id_lookup,
    how='left')

# %%
moving_sensors_data = moving_sensors_data[['observed_at', 'entity_type', 'entity_id', 'l', 'w']]

# %%
moving_sensors_data = moving_sensors_data.sort_values(by=['observed_at', 'entity_id']).reset_index(drop=True)

# %%
moving_sensors_data
# Out:
#              observed_at entity_type  entity_id         l         w
# 0    2018-03-13 23:36:00     teacher      11028  9.655660  2.234919
# 1    2018-03-13 23:36:00     teacher      11029  9.635034  2.289426
# 2    2018-03-13 23:36:00       child      28348  5.124096  1.287351
# 3    2018-03-13 23:36:00       child      28352  5.153526  1.362054
# 4    2018-03-13 23:36:00       child      28354  8.446923  4.507708
# 5    2018-03-13 23:36:00       child      30007  3.854473  3.567772
# 6    2018-03-13 23:36:00       child      36212  5.148084  1.549869
# 7    2018-03-13 23:36:00       child      37757  8.437763  4.551312
# 8    2018-03-13 23:36:00       child      37758  3.629785  3.549055
# 9    2018-03-13 23:36:00       child      37760  3.832900  3.510205
# 10   2018-03-13 23:36:00       child      38394  8.414899  4.506245
# 11   2018-03-13 23:36:00       child      55514  5.168075  1.533441
# 12   2018-03-13 23:36:00       child      57651  8.425577  4.324590
# 13   2018-03-13 23:36:10     teacher      11028  9.655660  2.234919
# 14   2018-03-13 23:36:10     teacher      11029  9.635034  2.289426
# 15   2018-03-13 23:36:10       child      28348  5.124096  1.287351
# 16   2018-03-13 23:36:10       child      28352  5.153526  1.362054
# 17   2018-03-13 23:36:10       child      28354  8.446923  4.507708
# 18   2018-03-13 23:36:10       child      30007  3.854473  3.567772
# 19   2018-03-13 23:36:10       child      36212  5.148084  1.549869
# 20   2018-03-13 23:36:10       child      37757  8.437763  4.551312
# 21   2018-03-13 23:36:10       child      37758  3.629785  3.549055
# 22   2018-03-13 23:36:10       child      37760  3.832900  3.510205
# 23   2018-03-13 23:36:10       child      38394  8.414899  4.506245
# 24   2018-03-13 23:36:10       child      55514  5.168075  1.533441
# 25   2018-03-13 23:36:10       child      57651  8.425577  4.324590
# 26   2018-03-13 23:36:20     teacher      11028  9.655660  2.234919
# 27   2018-03-13 23:36:20     teacher      11029  9.635034  2.289426
# 28   2018-03-13 23:36:20       child      28348  5.124096  1.287351
# 29   2018-03-13 23:36:20       child      28352  5.153526  1.362054
# ...                  ...         ...        ...       ...       ...
# 8264 2018-03-14 01:23:40       child      37760  3.756844  3.528686
# 8265 2018-03-14 01:23:40       child      38394  8.465999  4.580597
# 8266 2018-03-14 01:23:40       child      55514  5.265208  1.439371
# 8267 2018-03-14 01:23:40       child      57651  8.513320  4.340901
# 8268 2018-03-14 01:23:50     teacher      11028  9.776886  2.110122
# 8269 2018-03-14 01:23:50     teacher      11029  5.059857  1.447721
# 8270 2018-03-14 01:23:50       child      28348  3.724507  3.533056
# 8271 2018-03-14 01:23:50       child      28352  3.717349  3.502710
# 8272 2018-03-14 01:23:50       child      28354  5.086548  1.422751
# 8273 2018-03-14 01:23:50       child      30007  8.397499  4.318761
# 8274 2018-03-14 01:23:50       child      36212  5.106164  1.518721
# 8275 2018-03-14 01:23:50       child      37757  8.566187  4.473784
# 8276 2018-03-14 01:23:50       child      37758  9.640769  2.318698
# 8277 2018-03-14 01:23:50       child      37760  3.756844  3.528686
# 8278 2018-03-14 01:23:50       child      38394  8.465999  4.580597
# 8279 2018-03-14 01:23:50       child      55514  5.265208  1.439371
# 8280 2018-03-14 01:23:50       child      57651  8.513320  4.340901
# 8281 2018-03-14 01:24:00     teacher      11028  9.776886  2.110122
# 8282 2018-03-14 01:24:00     teacher      11029  5.059857  1.447721
# 8283 2018-03-14 01:24:00       child      28348  3.724507  3.533056
# 8284 2018-03-14 01:24:00       child      28352  3.717349  3.502710
# 8285 2018-03-14 01:24:00       child      28354  5.086548  1.422751
# 8286 2018-03-14 01:24:00       child      30007  8.397499  4.318761
# 8287 2018-03-14 01:24:00       child      36212  5.106164  1.518721
# 8288 2018-03-14 01:24:00       child      37757  8.566187  4.473784
# 8289 2018-03-14 01:24:00       child      37758  9.640769  2.318698
# 8290 2018-03-14 01:24:00       child      37760  3.756844  3.528686
# 8291 2018-03-14 01:24:00       child      38394  8.465999  4.580597
# 8292 2018-03-14 01:24:00       child      55514  5.265208  1.439371
# 8293 2018-03-14 01:24:00       child      57651  8.513320  4.340901
#
# [8294 rows x 5 columns]

# %% [markdown]
# ## Save the moving sensor ground truth data in dataframe format

# %%
moving_sensors_data.to_pickle(
    os.path.join(
        data_path,
        data_run_directory,
        'pickle/moving_sensors_data.pkl'))

# %% [markdown]
# ## (Re)load the moving sensor ground truth data in dataframe format

# %%
moving_sensors_data = pd.read_pickle(os.path.join(
        data_path,
        data_run_directory,
        'pickle/moving_sensors_data.pkl'))

# %%
moving_sensors_data
# Out:
#              observed_at entity_type  entity_id         l         w
# 0    2018-03-13 23:36:00     teacher      11028  9.655660  2.234919
# 1    2018-03-13 23:36:00     teacher      11029  9.635034  2.289426
# 2    2018-03-13 23:36:00       child      28348  5.124096  1.287351
# 3    2018-03-13 23:36:00       child      28352  5.153526  1.362054
# 4    2018-03-13 23:36:00       child      28354  8.446923  4.507708
# 5    2018-03-13 23:36:00       child      30007  3.854473  3.567772
# 6    2018-03-13 23:36:00       child      36212  5.148084  1.549869
# 7    2018-03-13 23:36:00       child      37757  8.437763  4.551312
# 8    2018-03-13 23:36:00       child      37758  3.629785  3.549055
# 9    2018-03-13 23:36:00       child      37760  3.832900  3.510205
# 10   2018-03-13 23:36:00       child      38394  8.414899  4.506245
# 11   2018-03-13 23:36:00       child      55514  5.168075  1.533441
# 12   2018-03-13 23:36:00       child      57651  8.425577  4.324590
# 13   2018-03-13 23:36:10     teacher      11028  9.655660  2.234919
# 14   2018-03-13 23:36:10     teacher      11029  9.635034  2.289426
# 15   2018-03-13 23:36:10       child      28348  5.124096  1.287351
# 16   2018-03-13 23:36:10       child      28352  5.153526  1.362054
# 17   2018-03-13 23:36:10       child      28354  8.446923  4.507708
# 18   2018-03-13 23:36:10       child      30007  3.854473  3.567772
# 19   2018-03-13 23:36:10       child      36212  5.148084  1.549869
# 20   2018-03-13 23:36:10       child      37757  8.437763  4.551312
# 21   2018-03-13 23:36:10       child      37758  3.629785  3.549055
# 22   2018-03-13 23:36:10       child      37760  3.832900  3.510205
# 23   2018-03-13 23:36:10       child      38394  8.414899  4.506245
# 24   2018-03-13 23:36:10       child      55514  5.168075  1.533441
# 25   2018-03-13 23:36:10       child      57651  8.425577  4.324590
# 26   2018-03-13 23:36:20     teacher      11028  9.655660  2.234919
# 27   2018-03-13 23:36:20     teacher      11029  9.635034  2.289426
# 28   2018-03-13 23:36:20       child      28348  5.124096  1.287351
# 29   2018-03-13 23:36:20       child      28352  5.153526  1.362054
# ...                  ...         ...        ...       ...       ...
# 8264 2018-03-14 01:23:40       child      37760  3.756844  3.528686
# 8265 2018-03-14 01:23:40       child      38394  8.465999  4.580597
# 8266 2018-03-14 01:23:40       child      55514  5.265208  1.439371
# 8267 2018-03-14 01:23:40       child      57651  8.513320  4.340901
# 8268 2018-03-14 01:23:50     teacher      11028  9.776886  2.110122
# 8269 2018-03-14 01:23:50     teacher      11029  5.059857  1.447721
# 8270 2018-03-14 01:23:50       child      28348  3.724507  3.533056
# 8271 2018-03-14 01:23:50       child      28352  3.717349  3.502710
# 8272 2018-03-14 01:23:50       child      28354  5.086548  1.422751
# 8273 2018-03-14 01:23:50       child      30007  8.397499  4.318761
# 8274 2018-03-14 01:23:50       child      36212  5.106164  1.518721
# 8275 2018-03-14 01:23:50       child      37757  8.566187  4.473784
# 8276 2018-03-14 01:23:50       child      37758  9.640769  2.318698
# 8277 2018-03-14 01:23:50       child      37760  3.756844  3.528686
# 8278 2018-03-14 01:23:50       child      38394  8.465999  4.580597
# 8279 2018-03-14 01:23:50       child      55514  5.265208  1.439371
# 8280 2018-03-14 01:23:50       child      57651  8.513320  4.340901
# 8281 2018-03-14 01:24:00     teacher      11028  9.776886  2.110122
# 8282 2018-03-14 01:24:00     teacher      11029  5.059857  1.447721
# 8283 2018-03-14 01:24:00       child      28348  3.724507  3.533056
# 8284 2018-03-14 01:24:00       child      28352  3.717349  3.502710
# 8285 2018-03-14 01:24:00       child      28354  5.086548  1.422751
# 8286 2018-03-14 01:24:00       child      30007  8.397499  4.318761
# 8287 2018-03-14 01:24:00       child      36212  5.106164  1.518721
# 8288 2018-03-14 01:24:00       child      37757  8.566187  4.473784
# 8289 2018-03-14 01:24:00       child      37758  9.640769  2.318698
# 8290 2018-03-14 01:24:00       child      37760  3.756844  3.528686
# 8291 2018-03-14 01:24:00       child      38394  8.465999  4.580597
# 8292 2018-03-14 01:24:00       child      55514  5.265208  1.439371
# 8293 2018-03-14 01:24:00       child      57651  8.513320  4.340901
#
# [8294 rows x 5 columns]

# %% [markdown]
# ## Restructure the moving sensor ground truth data for use in the model

# %%
x_continuous_t = np.full(
    (num_timesteps, variable_structure.num_x_continuous_vars),
    np.nan,
    dtype='float')
for t_index in range(num_timesteps):
    x_continuous_t[t_index] = variable_structure.sensor_x_continuous_data_parse_one_timestep(
        moving_sensors_data[moving_sensors_data['observed_at'] == timestamps[t_index]])

# %% [markdown]
# ## Save the moving sensor ground truth data in the format required by the model

# %%
np.savez(
    os.path.join(
        data_path,
        data_run_directory,
        'numpy/moving_sensor_data'),
    x_continuous_t = x_continuous_t)

# %% [markdown]
# ## Load the fixed sensor position data

# %%
fixed_sensors_data_input = pd.read_csv(
    os.path.join(
        data_path,
        data_run_directory,
        'csv/aster_180313_fixed_sensors.csv'))

# %%
fixed_sensors_data_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
# sensor_id    9 non-null int64
# l            9 non-null float64
# w            9 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 296.0 bytes

# %%
fixed_sensors_data_input
# Out:
#    sensor_id        l       w
# 0          1  12.1158  5.2324
# 1          2   6.9342  3.7338
# 2          3   4.2164  0.0000
# 3          4   0.5842  0.0000
# 4          5   2.2098  5.9436
# 5          6  10.9982  1.4986
# 6          7   9.6520  0.1524
# 7         48  12.9286  2.5400
# 8         49   3.3782  3.4798

# %% [markdown]
# ## Convert fixed sensor position data from sensor IDs to entity IDs

# %%
fixed_sensors_data = pd.merge(
    fixed_sensors_data_input,
    entity_id_lookup,
    how='left')

# %%
fixed_sensors_data = fixed_sensors_data[['entity_type', 'entity_id', 'l', 'w']]

# %%
fixed_sensors_data = fixed_sensors_data.sort_values(by=['entity_id']).reset_index(drop=True)

# %%
fixed_sensors_data
# Out:
#   entity_type  entity_id        l       w
# 0        area         29   4.2164  0.0000
# 1        area         31  12.1158  5.2324
# 2        area         36  12.9286  2.5400
# 3        area         49   6.9342  3.7338
# 4        area         50   0.5842  0.0000
# 5        area         51   2.2098  5.9436
# 6        area         52  10.9982  1.4986
# 7        area         53   9.6520  0.1524
# 8        area         54   3.3782  3.4798

# %% [markdown]
# ## Save the fixed sensor position data in dataframe format

# %%
pickle_directory = 'pickle/'
data_pickle_filename = 'fixed_sensors_data.pkl'

# %%
fixed_sensors_data.to_pickle(
    os.path.join(
        data_path,
        data_run_directory,
        'pickle/fixed_sensors_data.pkl'))

# %% [markdown]
# ## (Re)load the fixed sensor position data in dataframe format

# %%
fixed_sensors_data = pd.read_pickle(os.path.join(
        data_path,
        data_run_directory,
        'pickle/fixed_sensors_data.pkl'))

# %%
fixed_sensors_data
# Out:
#   entity_type  entity_id        l       w
# 0        area         29   4.2164  0.0000
# 1        area         31  12.1158  5.2324
# 2        area         36  12.9286  2.5400
# 3        area         49   6.9342  3.7338
# 4        area         50   0.5842  0.0000
# 5        area         51   2.2098  5.9436
# 6        area         52  10.9982  1.4986
# 7        area         53   9.6520  0.1524
# 8        area         54   3.3782  3.4798

# %% [markdown]
# ## Restructure the fixed sensor position data for use in the model

# %%
area_entity_ids
# Out:
# [29, 31, 36, 49, 50, 51, 52, 53, 54]

# %%
fixed_sensor_positions = np.full(
    (variable_structure.num_area_sensors, variable_structure.num_dimensions),
    np.nan,
    dtype='float')
for i in range(len(area_entity_ids)):
    fixed_sensor_positions[i, 0] = fixed_sensors_data.loc[fixed_sensors_data['entity_id'] == area_entity_ids[i], 'l']
    fixed_sensor_positions[i, 1] = fixed_sensors_data.loc[fixed_sensors_data['entity_id'] == area_entity_ids[i], 'w']

# %%
fixed_sensor_positions
# Out:
# array([[ 4.2164,  0.    ],
#        [12.1158,  5.2324],
#        [12.9286,  2.54  ],
#        [ 6.9342,  3.7338],
#        [ 0.5842,  0.    ],
#        [ 2.2098,  5.9436],
#        [10.9982,  1.4986],
#        [ 9.652 ,  0.1524],
#        [ 3.3782,  3.4798]])

# %% [markdown]
# ## Save the fixed sensor position data in the format required by the model

# %%
np.savez(
    os.path.join(
        data_path,
        data_run_directory,
        'numpy/fixed_sensor_positions'),
    fixed_sensor_positions = fixed_sensor_positions)

# %% [markdown]
# ## Save summaries of ping data in human readable format

# %%
period_timing_data
# Out:
#    period          start_time            end_time
# 0       1 2018-03-13 23:36:00 2018-03-13 23:52:00
# 1       2 2018-03-13 23:54:00 2018-03-14 01:24:00

# %%
timestamps.shape
# Out:
# (511,)

# %%
y_discrete_all_sensors_t.shape
# Out:
# (511, 26, 26)

# %%
y_continuous_all_sensors_t.shape
# Out:
# (511, 26, 26)

# %%
timestamps[6]
# Out:
# numpy.datetime64('2018-03-13T23:36:00.000000000')

# %%
timestamps [6 + (52-36)*6]
# Out:
# numpy.datetime64('2018-03-13T23:52:00.000000000')

# %%
timestamps [6 + (54-36)*6]
# Out:
# numpy.datetime64('2018-03-13T23:54:00.000000000')

# %%
timestamps[-1]
# Out:
# numpy.datetime64('2018-03-14T01:00:00.000000000')

# %%
y_discrete_all_sensors_first_period = y_discrete_all_sensors_t[6:(6 + (52 - 36)*6 + 1)]

# %%
y_discrete_all_sensors_second_period = y_discrete_all_sensors_t[(6 + (54 - 36)*6):]

# %%
y_continuous_all_sensors_first_period = y_continuous_all_sensors_t[6:(6 + (52 - 36)*6 + 1)]

# %%
y_continuous_all_sensors_second_period = y_continuous_all_sensors_t[(6 + (54 - 36)*6):]

# %%
y_discrete_all_sensors_first_period.shape
# Out:
# (97, 26, 26)

# %%
y_discrete_all_sensors_second_period.shape
# Out:
# (397, 26, 26)

# %%
y_continuous_all_sensors_first_period.shape
# Out:
# (97, 26, 26)

# %%
y_continuous_all_sensors_second_period.shape
# Out:
# (397, 26, 26)

# %%
np.sum(y_discrete_all_sensors_first_period==0)
# Out:
# 6275

# %%
np.sum(y_discrete_all_sensors_second_period==0)
# Out:
# 26059

# %%
ping_count_first_period = np.sum(y_discrete_all_sensors_first_period == 0, axis = 0)

# %%
ping_count_second_period = np.sum(y_discrete_all_sensors_second_period == 0, axis = 0)

# %%
mean_rssi_first_period = np.zeros_like(y_continuous_all_sensors_first_period[0])

# %%
mean_rssi_second_period = np.zeros_like(y_continuous_all_sensors_second_period[0])

# %%
for i in range(mean_rssi_first_period.shape[0]):
    for j in range(mean_rssi_first_period.shape[1]):
        if np.sum(y_discrete_all_sensors_first_period[:, i, j] == 0) > 0:
            mean_rssi_first_period[i, j] = np.mean(
                y_continuous_all_sensors_first_period[y_discrete_all_sensors_first_period[:, i, j] == 0, i, j])
        else:
            mean_rssi_first_period[i, j] = np.nan

# %%
for i in range(mean_rssi_second_period.shape[0]):
    for j in range(mean_rssi_second_period.shape[1]):
        if np.sum(y_discrete_all_sensors_second_period[:, i, j] == 0) > 0:
            mean_rssi_second_period[i, j] = np.mean(
                y_continuous_all_sensors_second_period[y_discrete_all_sensors_second_period[:, i, j] == 0, i, j])
        else:
            mean_rssi_second_period[i, j] = np.nan

# %%
variable_structure.entity_id_index
# Out:
# {'area_29': 17,
#  'area_31': 18,
#  'area_36': 19,
#  'area_49': 20,
#  'area_50': 21,
#  'area_51': 22,
#  'area_52': 23,
#  'area_53': 24,
#  'area_54': 25,
#  'child_28348': 0,
#  'child_28352': 1,
#  'child_28354': 2,
#  'child_30007': 3,
#  'child_36212': 4,
#  'child_37757': 5,
#  'child_37758': 6,
#  'child_37760': 7,
#  'child_38394': 8,
#  'child_55514': 9,
#  'child_57651': 10,
#  'material_30': 11,
#  'material_688554': 12,
#  'material_688561': 13,
#  'material_688570': 14,
#  'teacher_11028': 15,
#  'teacher_11029': 16}

# %%
num_entities = len(variable_structure.entity_id_index)

# %%
entity_types = []
entity_ids = []
indexes = []
for entity_type_id in variable_structure.entity_id_index:
    entity_type, entity_id = entity_type_id.split('_')
    index = variable_structure.entity_id_index[entity_type_id]
    entity_types.append(entity_type)
    entity_ids.append(entity_id)
    indexes.append(index)

# %%
active_entities = pd.DataFrame({
    'index': np.array(indexes, dtype='int'),
    'entity_type': np.array(entity_types, dtype='object'),
    'entity_id': np.array(entity_ids, dtype='int')
}).sort_values('index').reset_index(drop=True)

# %%
active_entities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
# entity_id      26 non-null int32
# entity_type    26 non-null object
# index          26 non-null int32
# dtypes: int32(2), object(1)
# memory usage: 496.0+ bytes

# %%
entity_id_lookup
# Out:
#     sensor_id entity_type  entity_id
# 0          18       child      28348
# 1          28       child      28349
# 2          26       child      28350
# 3          17       child      28352
# 4          16       child      28354
# 5          14       child      30007
# 6          19       child      36212
# 7          20       child      37757
# 8          11       child      37758
# 9          12       child      37760
# 10         15       child      38394
# 11         21       child      55514
# 12         13       child      57651
# 13         30     teacher      11028
# 14         31     teacher      11029
# 15         35    material         29
# 16         42    material         30
# 17         36    material         31
# 18         37    material         32
# 19         38    material         33
# 20         39    material         34
# 21         41    material     688554
# 22         44    material     688561
# 23         40    material     688570
# 24          3        area         29
# 25          1        area         31
# 26         48        area         36
# 27          2        area         49
# 28          4        area         50
# 29          5        area         51
# 30          6        area         52
# 31          7        area         53
# 32         49        area         54

# %%
active_entities_sensor_ids = pd.merge(
    active_entities,
    entity_id_lookup,
    how='left')

# %%
active_entities_sensor_ids
# Out:
#     entity_id entity_type  index  sensor_id
# 0       28348       child      0         18
# 1       28352       child      1         17
# 2       28354       child      2         16
# 3       30007       child      3         14
# 4       36212       child      4         19
# 5       37757       child      5         20
# 6       37758       child      6         11
# 7       37760       child      7         12
# 8       38394       child      8         15
# 9       55514       child      9         21
# 10      57651       child     10         13
# 11         30    material     11         42
# 12     688554    material     12         41
# 13     688561    material     13         44
# 14     688570    material     14         40
# 15      11028     teacher     15         30
# 16      11029     teacher     16         31
# 17         29        area     17          3
# 18         31        area     18          1
# 19         36        area     19         48
# 20         49        area     20          2
# 21         50        area     21          4
# 22         51        area     22          5
# 23         52        area     23          6
# 24         53        area     24          7
# 25         54        area     25         49

# %%
variable_names = active_entities_sensor_ids['entity_type'].values + '_' + active_entities_sensor_ids['sensor_id'].values.astype(str)

# %%
variable_names
# Out:
# array(['child_18', 'child_17', 'child_16', 'child_14', 'child_19',
#        'child_20', 'child_11', 'child_12', 'child_15', 'child_21',
#        'child_13', 'material_42', 'material_41', 'material_44',
#        'material_40', 'teacher_30', 'teacher_31', 'area_3', 'area_1',
#        'area_48', 'area_2', 'area_4', 'area_5', 'area_6', 'area_7',
#        'area_49'], dtype=object)

# %%
ping_count_first_period_dataframe = pd.DataFrame(
    ping_count_first_period,
    index=variable_names,
    columns=variable_names)

# %%
ping_count_second_period_dataframe = pd.DataFrame(
    ping_count_second_period,
    index=variable_names,
    columns=variable_names)

# %%
mean_rssi_first_period_dataframe = pd.DataFrame(
    mean_rssi_first_period,
    index=variable_names,
    columns=variable_names)

# %%
mean_rssi_second_period_dataframe = pd.DataFrame(
    mean_rssi_second_period,
    index=variable_names,
    columns=variable_names)

# %%
ping_count_first_period_dataframe.to_csv('./output/aster_180313/csv/ping_count_first_period.csv')

# %%
ping_count_second_period_dataframe.to_csv('./output/aster_180313/csv/ping_count_second_period.csv')

# %%
mean_rssi_first_period_dataframe.to_csv('./output/aster_180313/csv/mean_rssi_first_period.csv')

# %%
mean_rssi_second_period_dataframe.to_csv('./output/aster_180313/csv/mean_rssi_second_period.csv')

# %% [markdown]
# ## Calculate summaries of ping data in alternative way (as a check)

# %%
def period_labeler(timestamp):
    if timestamp >= period_timing_data.iloc[0, 1] and timestamp <= period_timing_data.iloc[0, 2]:
        return 1
    elif timestamp >= period_timing_data.iloc[1, 1] and timestamp <= period_timing_data.iloc[1, 2]:
        return 2
    else:
        return 0

# %%
period_timing_data.iloc[0, 1]
# Out:
# Timestamp('2018-03-13 23:36:00')

# %%
usable_data.loc[500, 'observed_at']
# Out:
# Timestamp('2018-03-13 23:36:10')

# %%
usable_data.loc[500, 'observed_at'] >= period_timing_data.iloc[0, 1] and usable_data.loc[500, 'observed_at'] < period_timing_data.iloc[0, 2]
# Out:
# True

# %%
usable_data['period'] = usable_data['observed_at'].map(period_labeler)

# %%
np.sum(usable_data['period'] == 1)
# Out:
# 6275

# %%
np.sum(usable_data['period'] == 2)
# Out:
# 26059

# %%
usable_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33378 entries, 0 to 33377
# Data columns (total 8 columns):
# classroom_id    33378 non-null int64
# local_id        33378 non-null int64
# local_type      33378 non-null object
# observed_at     33378 non-null datetime64[ns]
# remote_id       33378 non-null int64
# remote_type     33378 non-null object
# rssi            33378 non-null float64
# period          33378 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 2.0+ MB

# %%
active_entities_sensor_ids['variable_name'] = variable_names

# %%
active_entities_sensor_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 5 columns):
# entity_id        26 non-null int32
# entity_type      26 non-null object
# index            26 non-null int32
# sensor_id        26 non-null int64
# variable_name    26 non-null object
# dtypes: int32(2), int64(1), object(2)
# memory usage: 1.0+ KB

# %%
usable_data_sensor_ids = pd.merge(
    usable_data,
    active_entities_sensor_ids.rename(columns={
    'entity_id': 'remote_id',
    'entity_type': 'remote_type',
    'index': 'remote_index',
    'sensor_id': 'remote_sensor_id',
    'variable_name': 'remote_variable_name'}),
    how='left')

# %%
usable_data_sensor_ids = pd.merge(
    usable_data_sensor_ids,
    active_entities_sensor_ids.rename(columns={
    'entity_id': 'local_id',
    'entity_type': 'local_type',
    'index': 'local_index',
    'sensor_id': 'local_sensor_id',
    'variable_name': 'local_variable_name'}),
    how='left')

# %%
usable_data_sensor_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33378 entries, 0 to 33377
# Data columns (total 14 columns):
# classroom_id            33378 non-null int64
# local_id                33378 non-null int64
# local_type              33378 non-null object
# observed_at             33378 non-null datetime64[ns]
# remote_id               33378 non-null int64
# remote_type             33378 non-null object
# rssi                    33378 non-null float64
# period                  33378 non-null int64
# remote_index            33378 non-null int32
# remote_sensor_id        33378 non-null int64
# remote_variable_name    33378 non-null object
# local_index             33378 non-null int32
# local_sensor_id         33378 non-null int64
# local_variable_name     33378 non-null object
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(6), object(4)
# memory usage: 3.6+ MB

# %%
usable_data_reduced = usable_data_sensor_ids[[
    'period',
    'remote_index',
    'remote_variable_name',
    'local_index',
    'local_variable_name',
    'rssi']]

# %%
usable_data_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33378 entries, 0 to 33377
# Data columns (total 6 columns):
# period                  33378 non-null int64
# remote_index            33378 non-null int32
# remote_variable_name    33378 non-null object
# local_index             33378 non-null int32
# local_variable_name     33378 non-null object
# rssi                    33378 non-null float64
# dtypes: float64(1), int32(2), int64(1), object(2)
# memory usage: 1.5+ MB

# %%
ping_count_alt = pd.DataFrame(
    usable_data_reduced.groupby(['period', 'remote_index', 'remote_variable_name', 'local_index', 'local_variable_name']).size()).rename(columns={0: 'ping_count'}).reset_index().sort_values(['remote_index', 'local_index'])

# %%
ping_count_first_period_alt = pd.pivot_table(
    ping_count_alt[ping_count_alt['period'] == 1].drop(columns=['period']),
    values='ping_count',
    index=['remote_index'],
    columns=['local_index'])

# %%
ping_count_first_period_alt.index = variable_names[ping_count_first_period_alt.index.values]
ping_count_first_period_alt.columns = variable_names[ping_count_first_period_alt.columns.values]

# %%
ping_count_second_period_alt = pd.pivot_table(
    ping_count_alt[ping_count_alt['period'] == 2].drop(columns=['period']),
    values='ping_count',
    index=['remote_index'],
    columns=['local_index'])

# %%
ping_count_second_period_alt.index = variable_names[ping_count_second_period_alt.index.values]
ping_count_second_period_alt.columns = variable_names[ping_count_second_period_alt.columns.values]

# %%
mean_rssi_alt = usable_data_reduced.groupby(['period', 'remote_index', 'remote_variable_name', 'local_index', 'local_variable_name']).agg(np.mean).rename(columns={'rssi': 'mean_rssi'}).reset_index().sort_values(['remote_index', 'local_index'])

# %%
mean_rssi_first_period_alt = pd.pivot_table(
    mean_rssi_alt[mean_rssi_alt['period'] == 1].drop(columns=['period']),
    values='mean_rssi',
    index=['remote_index'],
    columns=['local_index'])

# %%
mean_rssi_first_period_alt.index = variable_names[mean_rssi_first_period_alt.index.values]
mean_rssi_first_period_alt.columns = variable_names[mean_rssi_first_period_alt.columns.values]

# %%
mean_rssi_second_period_alt = pd.pivot_table(
    mean_rssi_alt[mean_rssi_alt['period'] == 2].drop(columns=['period']),
    values='mean_rssi',
    index=['remote_index'],
    columns=['local_index'])

# %%
mean_rssi_second_period_alt.index = variable_names[mean_rssi_second_period_alt.index.values]
mean_rssi_second_period_alt.columns = variable_names[mean_rssi_second_period_alt.columns.values]

# %%
ping_count_first_period_alt.to_csv('./output/aster_180313/csv/ping_count_first_period_alt.csv')

# %%
ping_count_second_period_alt.to_csv('./output/aster_180313/csv/ping_count_second_period_alt.csv')

# %%
mean_rssi_first_period_alt.to_csv('./output/aster_180313/csv/mean_rssi_first_period_alt.csv')

# %%
mean_rssi_second_period_alt.to_csv('./output/aster_180313/csv/mean_rssi_second_period_alt.csv')
